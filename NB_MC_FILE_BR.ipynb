# %% [markdown]
# # Load file to bronze

# %% [markdown]
# ## Imports

# %%
import os
from datetime import datetime
import pandas as pd

# %% [markdown]
# ## Parameters

# %%
source_file_path = os.path.join(os.curdir, "menstrual_cycle.csv")

# %%
os.listdir()
# Out:
# ['.git', 'menstrual_cycle.csv', 'NB_MC_FILE_BR.ipynb', 'README.md']

# %%
bronze_file_name = "menstrual_cycle.parquet"
bronze_path = os.path.join(os.curdir, "Data_Lake","Bronze")
bronze_file_path = os.path.join(bronze_path, bronze_file_name)

# %%
os.makedirs(bronze_path)

# %% [markdown]
# ## Main

# %% [markdown]
# ### Cargar el csv a un DataFrame

# %%
menstrual_cycle_df = pd.read_csv(source_file_path)

# %%
# Comprobamos si el fichero se ha cargado correctamente
menstrual_cycle_df.head()
# Out:
#    User ID  Age    BMI  Stress Level Exercise Frequency  Sleep Hours  \
# 0      1.0   18  29.28             2           Moderate          5.4
# 1      1.0   18  29.28             2           Moderate          5.4
# 2      1.0   18  29.28             2           Moderate          5.4
# 3      1.0   18  29.28             2           Moderate          5.4
# 4      1.0   18  29.28             2           Moderate          5.4
#
#        Diet Cycle Start Date  Cycle Length  Period Length  \
# 0  Low Carb          52:34.9            26            7.0
# 1  Low Carb          52:34.9            32            5.0
# 2  Low Carb          52:34.9            41            7.0
# 3  Low Carb          52:34.9            27            3.0
# 4  Low Carb          52:34.9            42            5.0
#
#   Next Cycle Start Date  Symptoms
# 0               52:34.9  Headache
# 1               52:34.9   Fatigue
# 2               52:34.9   Fatigue
# 3               52:34.9   Fatigue
# 4               52:34.9    Cramps

# %% [markdown]
# ### Añadir el timestamp de carga

# %%
menstrual_cycle_df['_BronzeTimestamp'] = datetime.now()

# %%
menstrual_cycle_df.head()
# Out:
#    User ID  Age    BMI  Stress Level Exercise Frequency  Sleep Hours  \
# 0      1.0   18  29.28             2           Moderate          5.4
# 1      1.0   18  29.28             2           Moderate          5.4
# 2      1.0   18  29.28             2           Moderate          5.4
# 3      1.0   18  29.28             2           Moderate          5.4
# 4      1.0   18  29.28             2           Moderate          5.4
#
#        Diet Cycle Start Date  Cycle Length  Period Length  \
# 0  Low Carb          52:34.9            26            7.0
# 1  Low Carb          52:34.9            32            5.0
# 2  Low Carb          52:34.9            41            7.0
# 3  Low Carb          52:34.9            27            3.0
# 4  Low Carb          52:34.9            42            5.0
#
#   Next Cycle Start Date  Symptoms           _BronzeTimestamp
# 0               52:34.9  Headache 2025-11-06 17:24:13.627513
# 1               52:34.9   Fatigue 2025-11-06 17:24:13.627513
# 2               52:34.9   Fatigue 2025-11-06 17:24:13.627513
# 3               52:34.9   Fatigue 2025-11-06 17:24:13.627513
# 4               52:34.9    Cramps 2025-11-06 17:24:13.627513

# %% [markdown]
# ### Guardar el DataFrame en parquet

# %%
menstrual_cycle_df.to_parquet(bronze_file_path, index=False)
